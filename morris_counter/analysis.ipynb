# %%
# %config IPCompleter.greedy=True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('results.csv')

# %%
results
# Out:
#          n        state
# 0        0     2.000000
# 1        1     2.378414
# 2        2     2.828427
# 3        3     2.828427
# 4        4     4.000000
# ...    ...          ...
# 9995  9995  8192.000000
# 9996  9996  8192.000000
# 9997  9997  8192.000000
# 9998  9998  8192.000000
# 9999  9999  8192.000000
#
# [10000 rows x 2 columns]

# %%
x = np.linspace(0.0, 10000.0, 10000)
plt.figure(figsize=(13,13))
plt.plot(x, results['state'])
plt.plot(x, x)
plt.show()
